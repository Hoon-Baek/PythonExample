# %%
import re
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
['ai', 'ai']
# Out:
# ['ai', 'ai']
# ['ai', 'ai']

# %%
import re
txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
[]
# Out:
# []
# []

# %%
import re
txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
# Out:
# None

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_20320\3056546710.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt, 1)
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_20320\3056546710.py:3: DeprecationWarning: 'maxsplit' is passed as positional argument
#   x = re.split("\s", txt, 1)

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_20320\3056546710.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt, 1)
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_20320\3056546710.py:3: DeprecationWarning: 'maxsplit' is passed as positional argument
#   x = re.split("\s", txt, 1)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_20320\3838997704.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt, 2)
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_20320\3838997704.py:3: DeprecationWarning: 'count' is passed as positional argument
#   x = re.sub("\s", "9", txt, 2)

# %%
import re
txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain

# %%
try:
    print(x)
except:
    print("An exception occurred")
# Out:
# <re.Match object; span=(12, 17), match='Spain'>

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
price = 49
txt = f"It is very {'Expensive' if price>50 else 'Cheap'}"
print(txt)
# Out:
# It is very Cheap

# %%
def myconverter(x):
    return x * 0.3048
txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude

# %%
price = 49
txt = "The price is {} dollars"
print(txt.format(price))
# Out:
# The price is 49 dollars

# %%
result = None
if result is None:
    print("No result yet")
else:
    print("Result is ready")
# Out:
# No result yet

# %%
name = input("Enter your name:")
print(f"Hello {name}")
# Out:
# Hello Baek Jeong-Hoon

# %%
import math
x = input("Enter a number:")
y = math.sqrt(float(x))
print(f"The square root of {x} is {y}")
# Out:
# The square root of 7 is 2.6457513110645907
